# %% [markdown]
# <a href="https://colab.research.google.com/github/SI326/algorithm/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import time
import random
import matplotlib.pyplot as plt
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1


def time_linear_search(n):

    arr = [random.randint(1, 10000) for _ in range(n)]

    target = random.randint(1, 10000)

    start_time = time.time()
    linear_search(arr, target)


    end_time = time.time()


    return end_time - start_time


n_values = []
times = []


for n in range(1000, 10001, 1000):
    n_values.append(n)
    search_time = time_linear_search(n)
    times.append(search_time)


plt.plot(n_values, times, marker='o')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time Taken (seconds)')
plt.title('Time Taken for Linear Search vs List Size')
plt.grid(True)
plt.show()
